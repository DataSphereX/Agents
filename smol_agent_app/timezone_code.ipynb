# %%
import sys
import os

# Add the tools folder to the Python path
sys.path.append(os.path.join(os.getcwd(), 'tools'))

from final_answer import FinalAnswerTool

# Your existing imports
from smolagents import CodeAgent, DuckDuckGoSearchTool, HfApiModel, load_tool, tool
import datetime
import requests
import pytz
import yaml

from Gradio_UI import GradioUI
# Out:
# c:\Users\sarve\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
@tool
def my_custom_tool(arg1:str, arg2:int)-> str: # it's important to specify the return type
    # Keep this format for the tool description / args description but feel free to modify the tool
    """A tool that does nothing yet 
    Args:
        arg1: the first argument
        arg2: the second argument
    """
    return "What magic will you build ?"

@tool
def get_current_time_in_timezone(timezone: str) -> str:
    """A tool that fetches the current local time in a specified timezone.
    Args:
        timezone: A string representing a valid timezone (e.g., 'America/New_York').
    """
    try:
        # Create timezone object
        tz = pytz.timezone(timezone)
        # Get current time in that timezone
        local_time = datetime.datetime.now(tz).strftime("%Y-%m-%d %H:%M:%S")
        return f"The current local time in {timezone} is: {local_time}"
    except Exception as e:
        return f"Error fetching time for timezone '{timezone}': {str(e)}"

# %%
final_answer = FinalAnswerTool()
model = HfApiModel(
    max_tokens=2096,
    temperature=0.5,
    model_id='Qwen/Qwen2.5-Coder-32B-Instruct',
    custom_role_conversions=None,
)

with open("prompts.yaml", 'r') as stream:
    prompt_templates = yaml.safe_load(stream)
    
# We're creating our CodeAgent
agent = CodeAgent(
    model=model,
    tools=[final_answer], # add your tools here (don't remove final_answer)
    max_steps=6,
    verbosity_level=1,
    grammar=None,
    planning_interval=None,
    name=None,
    description=None,
    prompt_templates=prompt_templates
)

GradioUI(agent).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Hello                                                                                                           │
# │                                                                                                                 │
# ╰─ HfApiModel - Qwen/Qwen2.5-Coder-32B-Instruct ──────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("Hello!")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: Hello!
# [Step 0: Duration 6.79 seconds| Input tokens: 2,010 | Output tokens: 79]
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Time in Atlanta                                                                                                 │
# │                                                                                                                 │
# ╰─ HfApiModel - Qwen/Qwen2.5-Coder-32B-Instruct ──────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   from datetime import datetime
#   import pytz
#
#   # Get the current time in UTC
#   utc_now = datetime.now(pytz.utc)
#
#   # Define the timezone for Atlanta (Eastern Time)
#   atlanta_tz = pytz.timezone('America/New_York')
#
#   # Convert the UTC time to Atlanta time
#   atlanta_time = utc_now.astimezone(atlanta_tz)
#
#   # Format the time as a string
#   atlanta_time_str = atlanta_time.strftime('%Y-%m-%d %H:%M:%S %Z%z')
#
#   print(atlanta_time_str)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Warning to user: Code execution failed due to an unauthorized import - Consider passing said import under
# `additional_authorized_imports` when initializing your CodeAgent.
# Code execution failed at line 'import pytz' due to: InterpreterError: Import of pytz is not allowed. Authorized
# imports are: ['re', 'statistics', 'itertools', 'datetime', 'math', 'collections', 'queue', 'random', 'time',
# 'unicodedata', 'stat']
# [Step 1: Duration 8.11 seconds| Input tokens: 4,176 | Output tokens: 258]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   from datetime import datetime, timedelta
#
#   # Get the current time in UTC
#   utc_now = datetime.utcnow()
#
#   # Define the offset for Eastern Time (ET)
#   # Standard time is UTC-5, Daylight Saving Time is UTC-4
#   # We need to determine if daylight saving time is in effect
#
#   # Eastern Time is UTC-5, but we need to check for daylight saving time
#   # Daylight saving time in the US starts on the second Sunday in March and ends on the first Sunday in November
#   # Let's determine if the current date is within this range
#
#   # Get the current month and day
#   current_month = utc_now.month
#   current_day = utc_now.day
#
#   # Determine if daylight saving time is in effect
#   # Second Sunday in March: 8th, 15th, 22nd, 29th
#   # First Sunday in November: 1st, 8th, 15th, 22nd, 29th
#
#   # Calculate the second Sunday in March
#   second_sunday_march = 8 + (7 - (8 % 7)) % 7
#
#   # Calculate the first Sunday in November
#   first_sunday_november = 1 + (7 - (1 % 7)) % 7
#
#   # Check if daylight saving time is in effect
#   if (current_month == 3 and current_day >= second_sunday_march) or \
#      (current_month == 4) or \
#      (current_month == 5) or \
#      (current_month == 6) or \
#      (current_month == 7) or \
#      (current_month == 8) or \
#      (current_month == 9) or \
#      (current_month == 10) or \
#      (current_month == 11 and current_day < first_sunday_november):
#       # Daylight Saving Time is in effect, use UTC-4
#       et_offset = timedelta(hours=4)
#   else:
#       # Standard Time, use UTC-5
#       et_offset = timedelta(hours=5)
#
#   # Convert the UTC time to Eastern Time
#   atlanta_time = utc_now - et_offset
#
#   # Format the time as a string
#   atlanta_time_str = atlanta_time.strftime('%Y-%m-%d %H:%M:%S')
#
#   print(atlanta_time_str)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# 2025-03-12 00:37:14
#
# Out: None
# [Step 2: Duration 27.26 seconds| Input tokens: 6,794 | Output tokens: 826]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   from datetime import datetime, timedelta
#
#   # Get the current time in UTC
#   utc_now = datetime.utcnow()
#
#   # Define the offset for Eastern Time (ET)
#   # Standard time is UTC-5, Daylight Saving Time is UTC-4
#   # We need to determine if daylight saving time is in effect
#
#   # Eastern Time is UTC-5, but we need to check for daylight saving time
#   # Daylight saving time in the US starts on the second Sunday in March and ends on the first Sunday in November
#   # Let's determine if the current date is within this range
#
#   # Get the current month and day
#   current_month = utc_now.month
#   current_day = utc_now.day
#
#   # Determine if daylight saving time is in effect
#   # Second Sunday in March: 8th, 15th, 22nd, 29th
#   # First Sunday in November: 1st, 8th, 15th, 22nd, 29th
#
#   # Calculate the second Sunday in March
#   second_sunday_march = 8 + (7 - (8 % 7)) % 7
#
#   # Calculate the first Sunday in November
#   first_sunday_november = 1 + (7 - (1 % 7)) % 7
#
#   # Check if daylight saving time is in effect
#   if (current_month == 3 and current_day >= second_sunday_march) or \
#      (current_month == 4) or \
#      (current_month == 5) or \
#      (current_month == 6) or \
#      (current_month == 7) or \
#      (current_month == 8) or \
#      (current_month == 9) or \
#      (current_month == 10) or \
#      (current_month == 11 and current_day < first_sunday_november):
#       # Daylight Saving Time is in effect, use UTC-4
#       et_offset = timedelta(hours=4)
#   else:
#       # Standard Time, use UTC-5
#       et_offset = timedelta(hours=5)
#
#   # Convert the UTC time to Eastern Time
#   atlanta_time = utc_now - et_offset
#
#   # Format the time as a string
#   atlanta_time_str = atlanta_time.strftime('%Y-%m-%d %H:%M:%S')
#
#   # Print the formatted time string
#   print(atlanta_time_str)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# 2025-03-12 00:37:40
#
# Out: None
# [Step 3: Duration 25.72 seconds| Input tokens: 10,585 | Output tokens: 1,365]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   from datetime import datetime, timedelta
#
#   # Get the current time in UTC
#   utc_now = datetime.utcnow()
#   print(f"UTC Now: {utc_now}")
#
#   # Define the offset for Eastern Time (ET)
#   # Standard time is UTC-5, Daylight Saving Time is UTC-4
#   # We need to determine if daylight saving time is in effect
#
#   # Eastern Time is UTC-5, but we need to check for daylight saving time
#   # Daylight saving time in the US starts on the second Sunday in March and ends on the first Sunday in November
#   # Let's determine if the current date is within this range
#
#   # Get the current month and day
#   current_month = utc_now.month
#   current_day = utc_now.day
#   print(f"Current Month: {current_month}, Current Day: {current_day}")
#
#   # Determine if daylight saving time is in effect
#   # Second Sunday in March: 8th, 15th, 22nd, 29th
#   # First Sunday in November: 1st, 8th, 15th, 22nd, 29th
#
#   # Calculate the second Sunday in March
#   second_sunday_march = 8 + (7 - (8 % 7)) % 7
#   print(f"Second Sunday in March: {second_sunday_march}")
#
#   # Calculate the first Sunday in November
#   first_sunday_november = 1 + (7 - (1 % 7)) % 7
#   print(f"First Sunday in November: {first_sunday_november}")
#
#   # Check if daylight saving time is in effect
#   if (current_month == 3 and current_day >= second_sunday_march) or \
#      (current_month == 4) or \
#      (current_month == 5) or \
#      (current_month == 6) or \
#      (current_month == 7) or \
#      (current_month == 8) or \
#      (current_month == 9) or \
#      (current_month == 10) or \
#      (current_month == 11 and current_day < first_sunday_november):
#       # Daylight Saving Time is in effect, use UTC-4
#       et_offset = timedelta(hours=4)
#       print("Daylight Saving Time is in effect")
#   else:
#       # Standard Time, use UTC-5
#       et_offset = timedelta(hours=5)
#       print("Standard Time is in effect")
#
#   # Convert the UTC time to Eastern Time
#   atlanta_time = utc_now - et_offset
#   print(f"Atlanta Time: {atlanta_time}")
#
#   # Format the time as a string
#   atlanta_time_str = atlanta_time.strftime('%Y-%m-%d %H:%M:%S')
#   print(f"Formatted Atlanta Time: {atlanta_time_str}")
#
#   # Print the formatted time string
#   final_answer(atlanta_time_str)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# UTC Now: 2025-03-12 05:38:17.692882
# Current Month: 3, Current Day: 12
# Second Sunday in March: 14
# First Sunday in November: 7
# Standard Time is in effect
# Atlanta Time: 2025-03-12 00:38:17.692882
# Formatted Atlanta Time: 2025-03-12 00:38:17
#
# Out - Final answer: 2025-03-12 00:38:17
# [Step 4: Duration 37.45 seconds| Input tokens: 15,527 | Output tokens: 2,015]
# Keyboard interruption in main thread... closing server.
